# %%
from moviepy import VideoFileClip
# clip = ImageSequenceClip(['image_file1.jpeg', ...], fps=24)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-864661a48d58> in <module>()
# ----> 1 from moviepy import VideoFileClip
#       2 # clip = ImageSequenceClip(['image_file1.jpeg', ...], fps=24)
#
# ImportError: cannot import name 'VideoFileClip'
